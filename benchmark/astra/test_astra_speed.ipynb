# %%
import os
import platform
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import requests

# %% [markdown]
# ## Preparation
#
# ### Download Astra Binary
#
# If you already have an Astra installed on your PC, you can skip the section below

# %%
# Check if Astra is already installed
if not Path("Astra").is_file():
    # Download the binary for the current platform
    operating_system = platform.system()
    architecture = platform.machine()
    if operating_system == "Darwin" and architecture == "arm64":
        astra_binary_url = (
            "https://www.desy.de/~mpyflo/Astra_for_Mac_M1/Astra"  # Mac ARM
        )
    elif operating_system == "Darwin" and architecture == "x86_64":
        astra_binary_url = (
            "https://www.desy.de/~mpyflo/Astra_for_Mac_OSX/Astra"  # Mac Intel
        )
    elif operating_system == "Linux":
        astra_binary_url = (
            "https://www.desy.de/~mpyflo/Astra_for_64_Bit_Linux/Astra"  # Linux
        )
    elif operating_system == "Windows":
        astra_binary_url = (
            "https://www.desy.de/~mpyflo/Astra_for_WindowsPC/Astra.exe"  # Windows
        )

    response = requests.get(astra_binary_url)

    with open("Astra", "wb") as f:
        f.write(response.content)

    # Make the binary executable
    os.system("chmod +x Astra")

# %% [markdown]
# ### Simple test with 10k Macroparticles

# %%
os.system("./Astra ares_ea_testsmallbeam.in")
# Out:
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 16:48:21
#
#      Parameter file is:  ares_ea_testsmallbeam.in
#      test_smallbeam
#
#  Initialize element settings:
#      neglecting space charge forces
#
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#    10000 particles from file test_smallbeam.001
#
#      Particles taken into account      N =      10000
#      total charge                      Q =    -5.0000E-05 nC
#      horizontal beam position          x =     6.6752E-04 mm
#      vertical beam position            y =    -1.7471E-03 mm
#      longitudinal beam position        z =    -5.7163E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1751     mm
#      longitudinal beam size        sig z =     7.9472E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.1     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7725E-02 pi mrad mm
#      correlated divergence         cor x =     3.1832E-03 mrad
#      transverse beam emittance     eps y =     6.7757E-02 pi mrad mm
#      correlated divergence         cor y =     3.1967E-03 mrad
#      longitudinal beam emittance   eps z =      1.917     pi keV mm
#      correlated energy spread      cor z =     -37.79     keV
#      emittance ratio eps y/eps x         =     0.9995
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1750     mm
#                                        y =   0.1745     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6609     mrad
#  --------------------------------------------------------------------------
#  tracking of    10000 particles:
#      tracking will stop at             z =    2.046     m
#
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6825
#
#      **********************************************************************
#
#      Particles taken into account      N =      10000
#      total charge                      Q =    -5.0000E-05 nC
#      horizontal beam position          x =    -0.9200     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1239     mm
#      vertical beam size            sig y =     1.0162E-02 mm
#      longitudinal beam size        sig z =     7.9361E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.1     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.6972E-02 pi mrad mm
#      correlated divergence         cor x =     0.1460     mrad
#      transverse beam emittance     eps y =     0.1474     pi mrad mm
#      correlated divergence         cor y =     0.3233     mrad
#      longitudinal beam emittance   eps z =      1.918     pi keV mm
#      correlated energy spread      cor z =     -34.11     keV
#      emittance ratio eps y/eps x         =     0.6580
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =      10000
#      Electrons (total)                      =      10000
#      particles at the cathode               =          0
#      active particles                       =      10000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_testsmallbeam.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 16:48:32 2023
#      elapsed time   :                10.9 seconds
#      execution time :                10.9 seconds
#      system time    :                 0.0 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
# 0

# %% [markdown]
# ## Speed Benchmarks
#
# ### No Space Charge
#
# Comment: this will run about 10 min

# %%
# %%timeit
os.system("./Astra ares_ea_no_sc.in")
# Out:
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 16:48:32
#
#      Parameter file is:  ares_ea_no_sc.in
#      ares_ea_no_sc
#
#  Initialize element settings:
#      neglecting space charge forces
#
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6825
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1239     mm
#      vertical beam size            sig y =     1.0168E-02 mm
#      longitudinal beam size        sig z =     8.0002E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7253E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1479     pi mrad mm
#      correlated divergence         cor y =     0.3235     mrad
#      longitudinal beam emittance   eps z =      1.936     pi keV mm
#      correlated energy spread      cor z =     -36.57     keV
#      emittance ratio eps y/eps x         =     0.6575
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_no_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 16:50:21 2023
#      elapsed time   :               108.5 seconds
#      execution time :               108.5 seconds
#      system time    :                 0.0 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 16:50:21
#
#      Parameter file is:  ares_ea_no_sc.in
#      ares_ea_no_sc
#
#  Initialize element settings:
#      neglecting space charge forces
#
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6825
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1239     mm
#      vertical beam size            sig y =     1.0168E-02 mm
#      longitudinal beam size        sig z =     8.0002E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7253E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1479     pi mrad mm
#      correlated divergence         cor y =     0.3235     mrad
#      longitudinal beam emittance   eps z =      1.936     pi keV mm
#      correlated energy spread      cor z =     -36.57     keV
#      emittance ratio eps y/eps x         =     0.6575
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_no_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 16:52:10 2023
#      elapsed time   :               109.0 seconds
#      execution time :               108.9 seconds
#      system time    :                 0.0 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 16:52:10
#
#      Parameter file is:  ares_ea_no_sc.in
#      ares_ea_no_sc
#
#  Initialize element settings:
#      neglecting space charge forces
#
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6825
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1239     mm
#      vertical beam size            sig y =     1.0168E-02 mm
#      longitudinal beam size        sig z =     8.0002E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7253E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1479     pi mrad mm
#      correlated divergence         cor y =     0.3235     mrad
#      longitudinal beam emittance   eps z =      1.936     pi keV mm
#      correlated energy spread      cor z =     -36.57     keV
#      emittance ratio eps y/eps x         =     0.6575
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_no_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 16:54:00 2023
#      elapsed time   :               109.1 seconds
#      execution time :               109.1 seconds
#      system time    :                 0.0 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 16:54:00
#
#      Parameter file is:  ares_ea_no_sc.in
#      ares_ea_no_sc
#
#  Initialize element settings:
#      neglecting space charge forces
#
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6825
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1239     mm
#      vertical beam size            sig y =     1.0168E-02 mm
#      longitudinal beam size        sig z =     8.0002E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7253E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1479     pi mrad mm
#      correlated divergence         cor y =     0.3235     mrad
#      longitudinal beam emittance   eps z =      1.936     pi keV mm
#      correlated energy spread      cor z =     -36.57     keV
#      emittance ratio eps y/eps x         =     0.6575
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_no_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 16:55:49 2023
#      elapsed time   :               108.9 seconds
#      execution time :               108.8 seconds
#      system time    :                 0.0 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 16:55:49
#
#      Parameter file is:  ares_ea_no_sc.in
#      ares_ea_no_sc
#
#  Initialize element settings:
#      neglecting space charge forces
#
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6825
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1239     mm
#      vertical beam size            sig y =     1.0168E-02 mm
#      longitudinal beam size        sig z =     8.0002E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7253E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1479     pi mrad mm
#      correlated divergence         cor y =     0.3235     mrad
#      longitudinal beam emittance   eps z =      1.936     pi keV mm
#      correlated energy spread      cor z =     -36.57     keV
#      emittance ratio eps y/eps x         =     0.6575
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_no_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 16:57:39 2023
#      elapsed time   :               108.9 seconds
#      execution time :               108.9 seconds
#      system time    :                 0.0 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 16:57:39
#
#      Parameter file is:  ares_ea_no_sc.in
#      ares_ea_no_sc
#
#  Initialize element settings:
#      neglecting space charge forces
#
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6825
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1239     mm
#      vertical beam size            sig y =     1.0168E-02 mm
#      longitudinal beam size        sig z =     8.0002E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7253E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1479     pi mrad mm
#      correlated divergence         cor y =     0.3235     mrad
#      longitudinal beam emittance   eps z =      1.936     pi keV mm
#      correlated energy spread      cor z =     -36.57     keV
#      emittance ratio eps y/eps x         =     0.6575
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_no_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 16:59:28 2023
#      elapsed time   :               109.1 seconds
#      execution time :               109.0 seconds
#      system time    :                 0.0 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 16:59:28
#
#      Parameter file is:  ares_ea_no_sc.in
#      ares_ea_no_sc
#
#  Initialize element settings:
#      neglecting space charge forces
#
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6825
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1239     mm
#      vertical beam size            sig y =     1.0168E-02 mm
#      longitudinal beam size        sig z =     8.0002E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7253E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1479     pi mrad mm
#      correlated divergence         cor y =     0.3235     mrad
#      longitudinal beam emittance   eps z =      1.936     pi keV mm
#      correlated energy spread      cor z =     -36.57     keV
#      emittance ratio eps y/eps x         =     0.6575
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_no_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 17:01:18 2023
#      elapsed time   :               109.1 seconds
#      execution time :               109.1 seconds
#      system time    :                 0.0 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 17:01:18
#
#      Parameter file is:  ares_ea_no_sc.in
#      ares_ea_no_sc
#
#  Initialize element settings:
#      neglecting space charge forces
#
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6825
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1239     mm
#      vertical beam size            sig y =     1.0168E-02 mm
#      longitudinal beam size        sig z =     8.0002E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7253E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1479     pi mrad mm
#      correlated divergence         cor y =     0.3235     mrad
#      longitudinal beam emittance   eps z =      1.936     pi keV mm
#      correlated energy spread      cor z =     -36.57     keV
#      emittance ratio eps y/eps x         =     0.6575
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_no_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 17:03:08 2023
#      elapsed time   :               109.5 seconds
#      execution time :               109.4 seconds
#      system time    :                 0.0 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
# 1min 49s ± 187 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### With Space Charge
#
# Comment: this could run about 1 hour

# %%
# %%timeit
os.system("./Astra ares_ea_with_sc.in")
# Out:
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 17:03:08
#
#      Parameter file is:  ares_ea_with_sc.in
#      ares_ea_with_sc
#
#  Initialize element settings:
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#      space charge forces are INCLUDED
#      cylindrical symmetric algorithm
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6826
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1236     mm
#      vertical beam size            sig y =     9.9202E-03 mm
#      longitudinal beam size        sig z =     8.0005E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7108E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1478     pi mrad mm
#      correlated divergence         cor y =     0.3228     mrad
#      longitudinal beam emittance   eps z =      1.937     pi keV mm
#      correlated energy spread      cor z =     -35.54     keV
#      emittance ratio eps y/eps x         =     0.6570
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_with_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 17:07:33 2023
#      elapsed time   :               263.7 seconds
#      execution time :               263.6 seconds
#      system time    :                 0.1 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 17:07:33
#
#      Parameter file is:  ares_ea_with_sc.in
#      ares_ea_with_sc
#
#  Initialize element settings:
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#      space charge forces are INCLUDED
#      cylindrical symmetric algorithm
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6826
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1236     mm
#      vertical beam size            sig y =     9.9202E-03 mm
#      longitudinal beam size        sig z =     8.0005E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7108E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1478     pi mrad mm
#      correlated divergence         cor y =     0.3228     mrad
#      longitudinal beam emittance   eps z =      1.937     pi keV mm
#      correlated energy spread      cor z =     -35.54     keV
#      emittance ratio eps y/eps x         =     0.6570
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_with_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 17:11:58 2023
#      elapsed time   :               263.5 seconds
#      execution time :               263.5 seconds
#      system time    :                 0.1 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 17:11:58
#
#      Parameter file is:  ares_ea_with_sc.in
#      ares_ea_with_sc
#
#  Initialize element settings:
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#      space charge forces are INCLUDED
#      cylindrical symmetric algorithm
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6826
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1236     mm
#      vertical beam size            sig y =     9.9202E-03 mm
#      longitudinal beam size        sig z =     8.0005E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7108E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1478     pi mrad mm
#      correlated divergence         cor y =     0.3228     mrad
#      longitudinal beam emittance   eps z =      1.937     pi keV mm
#      correlated energy spread      cor z =     -35.54     keV
#      emittance ratio eps y/eps x         =     0.6570
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_with_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 17:16:23 2023
#      elapsed time   :               263.6 seconds
#      execution time :               263.5 seconds
#      system time    :                 0.1 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 17:16:23
#
#      Parameter file is:  ares_ea_with_sc.in
#      ares_ea_with_sc
#
#  Initialize element settings:
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#      space charge forces are INCLUDED
#      cylindrical symmetric algorithm
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6826
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1236     mm
#      vertical beam size            sig y =     9.9202E-03 mm
#      longitudinal beam size        sig z =     8.0005E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7108E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1478     pi mrad mm
#      correlated divergence         cor y =     0.3228     mrad
#      longitudinal beam emittance   eps z =      1.937     pi keV mm
#      correlated energy spread      cor z =     -35.54     keV
#      emittance ratio eps y/eps x         =     0.6570
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_with_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 17:20:48 2023
#      elapsed time   :               264.0 seconds
#      execution time :               264.0 seconds
#      system time    :                 0.1 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 17:20:48
#
#      Parameter file is:  ares_ea_with_sc.in
#      ares_ea_with_sc
#
#  Initialize element settings:
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#      space charge forces are INCLUDED
#      cylindrical symmetric algorithm
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6826
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1236     mm
#      vertical beam size            sig y =     9.9202E-03 mm
#      longitudinal beam size        sig z =     8.0005E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7108E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1478     pi mrad mm
#      correlated divergence         cor y =     0.3228     mrad
#      longitudinal beam emittance   eps z =      1.937     pi keV mm
#      correlated energy spread      cor z =     -35.54     keV
#      emittance ratio eps y/eps x         =     0.6570
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_with_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 17:25:14 2023
#      elapsed time   :               264.5 seconds
#      execution time :               264.4 seconds
#      system time    :                 0.1 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 17:25:14
#
#      Parameter file is:  ares_ea_with_sc.in
#      ares_ea_with_sc
#
#  Initialize element settings:
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#      space charge forces are INCLUDED
#      cylindrical symmetric algorithm
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6826
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1236     mm
#      vertical beam size            sig y =     9.9202E-03 mm
#      longitudinal beam size        sig z =     8.0005E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7108E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1478     pi mrad mm
#      correlated divergence         cor y =     0.3228     mrad
#      longitudinal beam emittance   eps z =      1.937     pi keV mm
#      correlated energy spread      cor z =     -35.54     keV
#      emittance ratio eps y/eps x         =     0.6570
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_with_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 17:29:37 2023
#      elapsed time   :               262.9 seconds
#      execution time :               262.8 seconds
#      system time    :                 0.1 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 17:29:37
#
#      Parameter file is:  ares_ea_with_sc.in
#      ares_ea_with_sc
#
#  Initialize element settings:
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#      space charge forces are INCLUDED
#      cylindrical symmetric algorithm
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6826
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1236     mm
#      vertical beam size            sig y =     9.9202E-03 mm
#      longitudinal beam size        sig z =     8.0005E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7108E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1478     pi mrad mm
#      correlated divergence         cor y =     0.3228     mrad
#      longitudinal beam emittance   eps z =      1.937     pi keV mm
#      correlated energy spread      cor z =     -35.54     keV
#      emittance ratio eps y/eps x         =     0.6570
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_with_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 17:34:01 2023
#      elapsed time   :               262.6 seconds
#      execution time :               262.5 seconds
#      system time    :                 0.1 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
#  --------------------------------------------------------------------------
#
#                 Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2022
#                         Tue Dec 12 17:34:01
#
#      Parameter file is:  ares_ea_with_sc.in
#      ares_ea_with_sc
#
#  Initialize element settings:
#  --------------------------------------------------------------------------
#  Quadrupole:
#
#      quadrupole no.:        1         at =   0.1750     m
#      quadrupole no.:        2         at =   0.7250     m
#      quadrupole no.:        3         at =    1.275     m
#  --------------------------------------------------------------------------
#  Dipole:
#
#      vertical dipole no.:   1
#      horizontal dipole no.:   2
#  --------------------------------------------------------------------------
#   100000 particles from file ACHIP_EA1_2021.1351.001
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =     8.2413E-04 mm
#      vertical beam position            y =    -1.7276E-03 mm
#      longitudinal beam position        z =    -5.7249E-06 m
#      horizontal beam size          sig x =     0.1749     mm
#      vertical beam size            sig y =     0.1752     mm
#      longitudinal beam size        sig z =     8.0114E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     6.7758E-02 pi mrad mm
#      correlated divergence         cor x =     3.1823E-03 mrad
#      transverse beam emittance     eps y =     6.7856E-02 pi mrad mm
#      correlated divergence         cor y =     3.1995E-03 mrad
#      longitudinal beam emittance   eps z =      1.934     pi keV mm
#      correlated energy spread      cor z =     -40.24     keV
#      emittance ratio eps y/eps x         =     0.9986
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   5.0896E-05 mm
#                                        y =  -5.4731E-04 mm
#      initial momentum                  p =    107.3     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#      gradient of quadrupole no.:   1     =    3.580     T/m
#      gradient of quadrupole no.:   2     =   -3.222     T/m
#      gradient of quadrupole no.:   3     =   -2.864     T/m
#      field strength of dipole no.:   1     =   1.7898E-02 T
#      field strength of dipole no.:   2     =  -3.5796E-02 T
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    2.046     m
#      time of flight is                 t =    6.825     ns
#      final momentum                    p =    107.3     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.1749     mm
#                                        y =   0.1746     mm
#
#      final position                    x =   -1.055     mm
#                                        y =   0.7411     mm
#      divergence                    px/pz =   -2.155     mrad
#                                    py/pz =   0.6607     mrad
#  --------------------------------------------------------------------------
#  tracking of   100000 particles:
#      tracking will stop at             z =    2.046     m
#
#      space charge forces are INCLUDED
#      cylindrical symmetric algorithm
#
#      final checkpoint at               z =    2.046     m
#      total number of iteration steps:          6826
#
#      **********************************************************************
#
#      Particles taken into account      N =     100000
#      total charge                      Q =    -5.0000E-04 nC
#      horizontal beam position          x =    -0.9201     mm
#      vertical beam position            y =     0.7524     mm
#      longitudinal beam position        z =      2.046     m
#      horizontal beam size          sig x =     0.1236     mm
#      vertical beam size            sig y =     9.9202E-03 mm
#      longitudinal beam size        sig z =     8.0005E-03 mm
#      average kinetic energy            E =      106.8     MeV
#      energy spread                    dE =      244.7     keV
#      average momentum                  P =      107.4     MeV/c
#      transverse beam emittance     eps x =     9.7108E-02 pi mrad mm
#      correlated divergence         cor x =     0.1459     mrad
#      transverse beam emittance     eps y =     0.1478     pi mrad mm
#      correlated divergence         cor y =     0.3228     mrad
#      longitudinal beam emittance   eps z =      1.937     pi keV mm
#      correlated energy spread      cor z =     -35.54     keV
#      emittance ratio eps y/eps x         =     0.6570
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =     100000
#      Electrons (total)                      =     100000
#      particles at the cathode               =          0
#      active particles                       =     100000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Phase-space distributions logged in    : ares_ea_with_sc.Log.001
#      No files saved
#
#      **********************************************************************
#
#
#
#      finished simulation  Tue Dec 12 17:38:25 2023
#      elapsed time   :               263.1 seconds
#      execution time :               263.0 seconds
#      system time    :                 0.1 seconds
#      Goodbye.
#  --------------------------------------------------------------------------
# 4min 24s ± 792 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
